# %%
import pandas as pd
import numpy as np

# %%
acs = pd.read_sas('../data/raw/spm_pu_2019.sas7bdat')

# %%
acs.head()
# Out:
#      filedate  serialno  sporder    st       puma     wt   age  sex  mar  \
# 0  20211015.0       1.0      1.0  12.0  1208623.0  171.0  68.0  2.0  1.0
# 1  20211015.0       1.0      2.0  12.0  1208623.0  156.0  70.0  1.0  1.0
# 2  20211015.0       1.0      3.0  12.0  1208623.0  185.0  29.0  2.0  5.0
# 3  20211015.0       2.0      1.0  18.0  1800300.0   68.0  80.0  1.0  1.0
# 4  20211015.0       2.0      2.0  18.0  1800300.0   67.0  73.0  2.0  1.0
#
#    education  ...  spm_fedtaxbc  spm_eitc  spm_fica  spm_sttax  \
# 0        4.0  ...       38587.5       0.0   18524.0    0.00000
# 1        4.0  ...       38587.5       0.0   18524.0    0.00000
# 2        4.0  ...       38587.5       0.0   18524.0    0.00000
# 3        3.0  ...         340.0       0.0       0.0  682.34003
# 4        2.0  ...         340.0       0.0       0.0  682.34003
#
#    spm_capwkccxpns  spm_wkxpns  spm_childcarexpns   spm_medxpns  spm_premium  \
# ...

# %%
acs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3088232 entries, 0 to 3088231
# Data columns (total 46 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   filedate           float64
#  1   serialno           float64
#  2   sporder            float64
#  3   st                 float64
#  4   puma               float64
#  5   wt                 float64
#  6   age                float64
#  7   sex                float64
#  8   mar                float64
#  9   education          float64
#  10  race               float64
#  11  hispanic           float64
#  12  offpoor            float64
#  13  moop_other         float64
#  14  medicare_partb     float64
#  15  tax_id             float64
#  16  agi                float64
#  17  spm_id             float64
#  18  spm_numper         float64
#  19  spm_numadults      float64
#  20  spm_numkids        float64
#  21  spm_wcohabit       float64
#  22  spm_wui_lt15       float64
#  23  spm_equivscale     float64
# ...

# %%
stata_url = r'https://www2.census.gov/programs-surveys/supplemental-poverty-measure/datasets/spm/spm_2019_pu.dta'
acs = pd.read_stata(
    stata_url,
    preserve_dtypes=True,
)

# %%
acs.head()

# %%
# from pandas.compat import StringIO
ipums_path = r'../data/raw/usa_00003.csv.gz'
ipums = pd.read_csv(ipums_path)
# ipums = pd.read_csv(StringIO(ipums_path), sep="\s+", skiprows=1, )
ipums.head()
# Out:
#    YEAR  SAMPLE  SERIAL       CBSERIAL  HHWT        CLUSTER  COUNTYFIP  \
# 0  2019  201901       1  2019010000088  11.0  2019000000011          0
# 1  2019  201901       2  2019010000096  70.0  2019000000021          0
# 2  2019  201901       3  2019010000153  20.0  2019000000031         15
# 3  2019  201901       4  2019010000198  79.0  2019000000041         15
# 4  2019  201901       5  2019010000205  53.0  2019000000051         97
#
#    STRATA  GQ
# 0  220001   4
# 1  100001   3
# 2  110001   4
# 3  110001   3
# 4  270101   3
